# %%
import numpy as np

# %%
x = [[-4,2],[-2,1],[-1,-1],[2,2],[1,-2]]
y = [1,1,-1,-1,-1]

#x = [[1,0],[-1,10],[-1,-1]]
#y = [-1,1,1]

print(x[0])
print(y[0])

#x1 = np.array([-1,-1]); y1 = 1
#x2 = np.array([1,0]); y2 = -1
#x3 = np.array([-1,1.5]); y3 = 1
#x3 = np.array([-1,10]); y3 = 1

#X = np.array([[-1,-1],[1,0],[-1,1.5]])
# Out:
# [-4, 2]
# 1

# %%
theta = np.array([-6,5])    #vector
theta_hat = -4    #scalar
thetas = []
mistakes = 0
T = 10

for t in range(T):
    #print(f'Tentative {t+1}')
    for i in range(len(x)):
        
        print(f't={t} i={i+1} ')
        print(f'x({i+1}):',x[i],f'\t\ty({i+1}):',y[i]) #,f'\t\ttheta_{t+1}{i+1}:',theta)
                        
        if np.multiply(y[i],np.add(np.dot(theta,x[i]),theta_hat)) <= 0:
            theta = theta + np.multiply(y[i],x[i])
            theta_hat = theta_hat + y[i]
            
            mistakes += 1
            thetas.append(theta)
            print('Updated Theta: ', theta, 'Updated Theta_hat: ', theta_hat)
        #else:
            #print('sign: + ', theta)


        #print(f'y*theta.x({i+1}):',np.multiply(y[i],np.dot(theta,x[i])))
        #print('theta:',theta)
        print('\n')
print('Total mistakes: ',mistakes)
print('All thetas:',thetas)
print('theta_hat:',theta_hat)
# Out:
# t=0 i=1
# x(1): [-4, 2] 		y(1): 1
#
#
# t=0 i=2
# x(2): [-2, 1] 		y(2): 1
#
#
# t=0 i=3
# x(3): [-1, -1] 		y(3): -1
#
#
# t=0 i=4
# x(4): [2, 2] 		y(4): -1
#
#
# t=0 i=5
# x(5): [1, -2] 		y(5): -1
#
#
# t=1 i=1
# x(1): [-4, 2] 		y(1): 1
#
#
# t=1 i=2
# x(2): [-2, 1] 		y(2): 1
#
#
# t=1 i=3
# x(3): [-1, -1] 		y(3): -1
#
#
# t=1 i=4
# x(4): [2, 2] 		y(4): -1
#
#
# t=1 i=5
# x(5): [1, -2] 		y(5): -1
#
#
# t=2 i=1
# x(1): [-4, 2] 		y(1): 1
#
#
# t=2 i=2
# x(2): [-2, 1] 		y(2): 1
#
#
# t=2 i=3
# x(3): [-1, -1] 		y(3): -1
#
#
# t=2 i=4
# x(4): [2, 2] 		y(4): -1
#
#
# t=2 i=5
# x(5): [1, -2] 		y(5): -1
#
#
# t=3 i=1
# x(1): [-4, 2] 		y(1): 1
#
#
# t=3 i=2
# x(2): [-2, 1] 		y(2): 1
#
#
# t=3 i=3
# x(3): [-1, -1] 		y(3): -1
#
#
# t=3 i=4
# x(4): [2, 2] 		y(4): -1
#
#
# t=3 i=5
# x(5): [1, -2] 		y(5): -1
#
#
# t=4 i=1
# x(1): [-4, 2] 		y(1): 1
#
#
# t=4 i=2
# x(2): [-2, 1] 		y(2): 1
#
#
# t=4 i=3
# x(3): [-1, -1] 		y(3): -1
#
#
# t=4 i=4
# x(4): [2, 2] 		y(4): -1
#
#
# t=4 i=5
# x(5): [1, -2] 		y(5): -1
#
#
# t=5 i=1
# x(1): [-4, 2] 		y(1): 1
#
#
# t=5 i=2
# x(2): [-2, 1] 		y(2): 1
#
#
# t=5 i=3
# x(3): [-1, -1] 		y(3): -1
#
#
# t=5 i=4
# x(4): [2, 2] 		y(4): -1
#
#
# t=5 i=5
# x(5): [1, -2] 		y(5): -1
#
#
# t=6 i=1
# x(1): [-4, 2] 		y(1): 1
#
#
# t=6 i=2
# x(2): [-2, 1] 		y(2): 1
#
#
# t=6 i=3
# x(3): [-1, -1] 		y(3): -1
#
#
# t=6 i=4
# x(4): [2, 2] 		y(4): -1
#
#
# t=6 i=5
# x(5): [1, -2] 		y(5): -1
#
#
# t=7 i=1
# x(1): [-4, 2] 		y(1): 1
#
#
# t=7 i=2
# x(2): [-2, 1] 		y(2): 1
#
#
# t=7 i=3
# x(3): [-1, -1] 		y(3): -1
#
#
# t=7 i=4
# x(4): [2, 2] 		y(4): -1
#
#
# t=7 i=5
# x(5): [1, -2] 		y(5): -1
#
#
# t=8 i=1
# x(1): [-4, 2] 		y(1): 1
#
#
# t=8 i=2
# x(2): [-2, 1] 		y(2): 1
#
#
# t=8 i=3
# x(3): [-1, -1] 		y(3): -1
#
#
# t=8 i=4
# x(4): [2, 2] 		y(4): -1
#
#
# t=8 i=5
# x(5): [1, -2] 		y(5): -1
#
#
# t=9 i=1
# x(1): [-4, 2] 		y(1): 1
#
#
# t=9 i=2
# x(2): [-2, 1] 		y(2): 1
#
#
# t=9 i=3
# x(3): [-1, -1] 		y(3): -1
#
#
# t=9 i=4
# x(4): [2, 2] 		y(4): -1
#
#
# t=9 i=5
# x(5): [1, -2] 		y(5): -1
#
#
# Total mistakes:  0
# All thetas: []
# theta_hat: -4

# %%
theta = [0,0]
print('x(i):',x1)
print('y(i):',y1)
print('y(i).x(i)',np.dot(x1,y1))
print('theta.x(i):',np.dot(theta,x1))
print('sign:', '+' if np.dot(theta,x1) > 0 else '0 or -')
theta = np.add(theta,np.dot(x1,y1))
print('theta:',theta)

print('\nx(i):',x2)
print('y(i):',y2)
print('y(i).x(i)',np.dot(y2,x2))
theta = np.add(theta,np.dot(x2,y2))
print('theta.x(i):',np.dot(theta,x2))
print('sign:', '+' if np.dot(theta,x2) > 0 else '0 or -')
print('theta:',theta)

print('\nx(i):',x3)
print('y(i):',y3)
print('y(i).x(i)',np.dot(y3,x3))
theta = np.add(theta,np.dot(x3,y3))
print('theta.x(i):',np.dot(theta,x3))
print('sign:', '+' if np.dot(theta,x3) > 0 else '0 or -')
print('theta:',theta)
# Out:
# x(i): [-1 -1]
# y(i): 1
# y(i).x(i) [-1 -1]
# theta.x(i): 0
# sign: 0 or -
# theta: [-1 -1]
#
# x(i): [1 0]
# y(i): -1
# y(i).x(i) [-1  0]
# theta.x(i): -2
# sign: 0 or -
# theta: [-2 -1]
#
# x(i): [-1.   1.5]
# y(i): 1
# y(i).x(i) [-1.   1.5]
# theta.x(i): 3.75
# sign: +
# theta: [-3.   0.5]
